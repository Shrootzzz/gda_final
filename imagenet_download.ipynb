# %%
from bs4 import BeautifulSoup
import numpy as np 
import requests
import urllib
import cv2

# %%
general_url = "http://image-net.org/api/text/imagenet.synset.geturls?wnid="

# %%
def url_to_image(url):
    # download the image, convert it to a NumPy array, and then read
    # it into OpenCV format
    resp = urllib.request.urlopen(url, timeout=5)
    image = np.asarray(bytearray(resp.read()), dtype="uint8")
    image = cv2.imdecode(image, cv2.IMREAD_COLOR)
 
    # return the image
    return image

def get_url(id_, general_url=general_url):
    print(general_url + id_)
    page = requests.get(general_url + id_).content
    soup = BeautifulSoup(page, 'html.parser')
    return soup

def soups_from_ids(ids):
    soups = {key: "" for key in ids}
    for id_ in ids:
        soup = get_url(ids[id_])
        soups[id_] = soup
    return soups


def download_images(soups):
    missing = 0
    for key, soup in soups.items():
        img_num = 1
        path = '/datasets/' + key + '/'
        print(path)
        urls = str(soup).split('\r\n')
        print(len(urls))
        print('processing %s images' % key)
        for url in urls:
            if img_num > 500:
                break
            try:
                print(url)

                img = url_to_image(url)
                if img is not None:
                    name = str(key) + '_' + str(img_num) + '.jpg'
                    print(path+name)

                    cv2.imwrite(name, img)
                    img_num += 1
            except (urllib.error.HTTPError, urllib.error.URLError, ValueError) as e:
                missing += 1
            except TimeoutError as e:
                continue 
                missing += 1
            except:
                missing += 1
            
    print('missing images: ', missing)

# %%
ids = {'dog': "n02083346",
#        'cat': "n02120997",
#        'snake': "n01726692" ,
#        'lizard':"n01674464", 
#        'horses': "n02374451",
#        'bovine':"n02402010",
#        'deer': "n02430045"
#         'egyption_cat': "n02124075"
      }

    
soups = soups_from_ids(ids)

download_images(soups)
# Out:
# http://image-net.org/api/text/imagenet.synset.geturls?wnid=n02083346
# /datasets/dog/
# 1
# processing dog images
#
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN"
#    "http://www.w3.org/TR/html4/loose.dtd">
#
# <html lang="en">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <title>ImageNet</title>
# <script src="https://www.google.com/recaptcha/api.js"></script>
# <link href="/static_files/style.css" rel="stylesheet" type="text/css"/>
# <link href="/static_files/favicon.ico" rel="shortcut icon"/>
# <link href="/static_files/favicon.png" rel="icon" type="image/png"/>
# <script language="JavaScript" src="/static_files/index_files/dropdownmenu.js">
# </script>
# <script language="javascript" src="/gpviewui/gpviewui.nocache.js" type="text/javascript"></script>
# <link href="/GPViewUI.css" rel="stylesheet" type="text/css"/>
# <script type="text/javascript"> function showemail(d,u)
# {
#   var email = u + "@" + d;
#   document.write("<a href=mailto:"+email+">"+email+"</a>");
# }
# </script>
# <script src="http://cdn.mathjax.org/mathjax/latest/MathJax.js?config=TeX-AMS-MML_HTMLorMML" type="text/javascript">
#   MathJax.Hub.Config({
#     extensions: ["tex2jax.js"],
#     "HTML-CSS": { scale: 100 }
#   });
# </script>
# <script type="text/x-mathjax-config">
#     MathJax.Hub.Config({tex2jax: {inlineMath: [['$','$'], ['\\(','\\)']]}});
# </script>
# <script src="http://cdn.mathjax.org/mathjax/latest/MathJax.js?config=TeX-AMS-MML_HTMLorMML" type="text/javascript">
# </script>
# <div id="wrap">
# <div id="header">
# <div id="l"><a href="/index"><img src="/static_files/index_files/logo.jpg"/></a></div>
# <div id="r">
# <div id="stats">14,197,122 images, 21841 synsets indexed    </div>
# <ul id="sddm">
# <li><a href="/index"> Home<sup>  </sup></a>
# </li>
# <li><a href="/download" onmouseout="mclosetime()" onmouseover="mopen('download')"> Download<sup>  </sup></a>
# </li>
# <li><a href="/challenges/LSVRC/index" onmouseout="mclosetime()" onmouseover="mopen('challenge')"> Challenges<sup>  </sup></a>
# </li>
# <!--        <li><a href="projects">&nbsp;&nbsp;Projects<sup>&nbsp;&nbsp;</sup></a>-->
# <!--        <li><a href="about-people">&nbsp;&nbsp;People<sup>&nbsp;&nbsp;</sup></a> -->
# <li><a href="/about" onmouseout="mclosetime()" onmouseover="mopen('overview')">  About<sup>  </sup></a>
# </li>
# </ul>
# </div>
# </div>
# <div id="top">
# <div id="topi">
#       Not logged in. <a href="/login">Login</a> | <a href="/signup">Signup</a> </div>
# </div>
# </div><h3>
# Oops!
# </h3>
# <br clear="all"/>
# <div class="hr"></div>
# The URL is not valid.
#
# <br clear="all"/>
# <p>
# </p></head></html>
# <div class="roundedcornr_bottom_413229"><div></div></div>
# <!--/end rounded corner box-->
# <!--/main-->
# <div class="roundedcornr_box_823035">
# <div class="roundedcornr_top_823035"><div></div></div>
# <div class="roundedcornr_content_823035">
# <script type="text/javascript"> function showemail(d,u)
# {
#   var email = u + "@" + d;
#   document.write("<a href=mailto:"+email+">"+email+"</a>");
# }
# </script>
# <div id="footer">
# <p> © 2020 <a href="http://vision.stanford.edu/">Stanford Vision Lab, </a><a href="http://www.stanford.edu">Stanford University</a>, <a href="http://www.princeton.edu">Princeton University</a>   <a href="mailto:imagenet.help.desk@gmail.com">imagenet.help.desk@gmail.com</a>    <a href="https://uit.stanford.edu/security/copyright-infringement">Copyright infringement</a> </p>
# </div>
# <!--footer-->
# </div>
# <div class="roundedcornr_bottom_823035"><div></div></div>
# </div><!--/end rounded corner box-->
# <!--/wrap-->
# <script type="text/javascript">
# 		       var gaJsHost = (("https:" == document.location.protocol) ? "https://ssl." : "http://www.");
# document.write(unescape("%3Cscript src='" + gaJsHost + "google-analytics.com/ga.js' type='text/javascript'%3E%3C/script%3E"));
# </script>
# <script type="text/javascript">
#   try {
#   var pageTracker = _gat._getTracker("UA-7472388-1");
#   pageTracker._trackPageview();
# } catch(err) {}</script>
#
#
#
# missing images:  1
